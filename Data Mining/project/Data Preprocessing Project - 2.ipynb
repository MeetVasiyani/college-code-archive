# %% [markdown]
# #### Read CSV

# %%
import pandas as pd

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# #### 1. First 5 Rows

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# #### 2. Last 5 rows

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# #### 3. Random Rows

# %%
df.sample(5,random_state=10)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 620   57    1   0       152   274    0        1       88      1      1.2
# 181   64    1   3       110   211    0        0      144      1      1.8
# 546   70    1   0       130   322    0        0      109      0      2.4
# 618   49    1   1       130   266    0        1      171      0      0.6
# 822   60    1   0       130   253    0        1      144      1      1.4
#
#      slope  ca  thal  target
# 620      1   1     3       0
# 181      1   0     2       1
# 546      1   3     2       0
# 618      2   0     2       1
# 822      2   1     3       0

# %% [markdown]
# #### 4. Number of Rows and Columns

# %%
df.shape
# Out:
# (1025, 14)

# %% [markdown]
# #### 5. List of Column Names

# %%
df.columns.to_list()
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal',
#  'target']

# %% [markdown]
# #### 6. Datatypes of each column

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# #### 7. Basic information of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# #### 8. Numeric Description of Dataset

# %%
df.describe(include='all')
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# #### 9. Distinct values per column

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %% [markdown]
# #### 10. Number of Missing Values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# #### 11. Number of Males and Females

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %% [markdown]
# #### 12. Remove Duplicates from the Dataset

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %% [markdown]
# #### 13. Change Datatypes of few Columns

# %%
df['thalach'] = df['thalach'].astype('float')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1    168.0      0      1.0
# 1     53    1   0       140   203    1        0    155.0      1      3.1
# 2     70    1   0       145   174    0        1    125.0      1      2.6
# 3     61    1   0       148   203    0        1    161.0      0      0.0
# 4     62    0   0       138   294    1        1    106.0      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0    115.0      0      1.5
# 733   44    0   2       108   141    0        1    175.0      0      0.6
# 739   52    1   0       128   255    0        1    161.0      1      0.0
# 843   59    1   3       160   273    0        0    125.0      0      0.0
# 878   54    1   0       120   188    0        1    113.0      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %% [markdown]
# #### 14. Add Diabetes Column

# %%
import numpy as np

df['Diabetes'] = np.where(df['fbs'] == 1, 'Diabetic', 'Non Diabetic')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1    168.0      0      1.0
# 1     53    1   0       140   203    1        0    155.0      1      3.1
# 2     70    1   0       145   174    0        1    125.0      1      2.6
# 3     61    1   0       148   203    0        1    161.0      0      0.0
# 4     62    0   0       138   294    1        1    106.0      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0    115.0      0      1.5
# 733   44    0   2       108   141    0        1    175.0      0      0.6
# 739   52    1   0       128   255    0        1    161.0      1      0.0
# 843   59    1   3       160   273    0        0    125.0      0      0.0
# 878   54    1   0       120   188    0        1    113.0      0      1.4
#
#      slope  ca  thal  target      Diabetes
# 0        2   2     3       0  Non Diabetic
# ...

# %% [markdown]
# #### 15. Drop added Column

# %%
df.drop('Diabetes', axis=1, inplace=True)
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1    168.0      0      1.0
# 1     53    1   0       140   203    1        0    155.0      1      3.1
# 2     70    1   0       145   174    0        1    125.0      1      2.6
# 3     61    1   0       148   203    0        1    161.0      0      0.0
# 4     62    0   0       138   294    1        1    106.0      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0    115.0      0      1.5
# 733   44    0   2       108   141    0        1    175.0      0      0.6
# 739   52    1   0       128   255    0        1    161.0      1      0.0
# 843   59    1   3       160   273    0        0    125.0      0      0.0
# 878   54    1   0       120   188    0        1    113.0      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %% [markdown]
# #### 16. Correlation Matrix

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %% [markdown]
# #### 17. Most Age patients

# %%
df['age'].value_counts().head(10)
# Out:
# age
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 60    11
# 62    11
# 44    11
# 56    11
# Name: count, dtype: int64

# %% [markdown]
# #### 18. Patients per chest pain type

# %%
df.groupby('cp').size()
# Out:
# cp
# 0    143
# 1     50
# 2     86
# 3     23
# dtype: int64

# %% [markdown]
# #### 19. Cross Tabulation Patients vs Heart Disease

# %%
pd.crosstab(df['sex'], df['target'], margins=True)
# Out:
# target    0    1  All
# sex
# 0        24   72   96
# 1       114   92  206
# All     138  164  302

# %% [markdown]
# #### 20. Covariance Matrix

# %%
df.cov()
# Out:
#                 age       sex        cp    trestbps         chol       fbs  \
# age       81.865757 -0.400761 -0.589283   44.991573    97.031561  0.385635
# sex       -0.400761  0.217553 -0.024906   -0.472245    -4.720930  0.007657
# cp        -0.589283 -0.024906  1.065114    0.842622    -3.882060  0.035346
# trestbps  44.991573 -0.472245  0.842622  308.472817   113.853821  1.115883
# chol      97.031561 -4.720930 -3.882060  113.853821  2678.423588  0.210963
# fbs        0.385635  0.007657  0.035346    1.115883     0.210963  0.127225
# restecg   -0.531110 -0.014807  0.022563   -1.065851    -4.018272 -0.015588
# thalach  -81.904755 -0.496095  6.934435  -19.317793    -6.292359 -0.058569
# exang      0.396570  0.031462 -0.190678    0.565906     1.559801  0.004147
# oldpeak    2.165226  0.053264 -0.175836    3.969653     3.010631  0.001870
# slope     -0.915161 -0.009483  0.074322   -1.329960     0.013289 -0.012893
# ...

# %% [markdown]
# #### 21. Heart disease rate by thalassemia type

# %%
df.groupby('thal')['target'].mean()
# Out:
# thal
# 0    0.500000
# 1    0.333333
# 2    0.781818
# 3    0.239316
# Name: target, dtype: float64

# %% [markdown]
# #### 22. Average Age without Disease

# %%
avg = df[df['target']==1]['age'].mean()
print("Average Age without Disease : ",avg)
# Out:
# Average Age without Disease :  52.58536585365854

# %% [markdown]
# #### 23. Highest Cholestrol

# %%
df.nlargest(5,'chol')
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 158   67    0   2       115   564    0        0    160.0      0      1.6
# 123   65    0   2       140   417    1        0    157.0      0      0.8
# 179   56    0   0       134   409    0        0    150.0      1      1.9
# 450   63    0   0       150   407    0        0    154.0      0      4.0
# 255   62    0   0       140   394    0        0    157.0      0      1.2
#
#      slope  ca  thal  target
# 158      1   0     3       1
# 123      2   1     2       1
# 179      1   2     3       0
# 450      1   3     3       0
# 255      1   0     2       1

# %% [markdown]
# #### 24. Plotting Heart Disease by Gender

# %%
df.groupby('sex')['target'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# #### 25. Heart Disease by Number of Major Vessels

# %%
df.groupby('ca')['target'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='ca'>
